# %%
# utils_pde_poisson2d.py
# ---------------------------------------------------------------------
# 2-D Poisson equation on Ω = (0,1) × (0,1)
#   Δu(x,y) + 2π² sin(πx) sin(πy) = 0,
# with homogeneous Dirichlet boundaries u = 0 on ∂Ω.
# The analytic solution is  u*(x,y) = sin(πx)·sin(πy).
# ---------------------------------------------------------------------
from interface_pde import BasePDE

import torch
import math


class Poisson2D(BasePDE):
    """2-D Poisson equation with zero Dirichlet BC on the unit square."""

    def __init__(self,
                 domain=((0.0, 1.0), (0.0, 1.0)),
                 true_solution=lambda xy: torch.sin(math.pi * xy[..., 0:1]) *
                                           torch.sin(math.pi * xy[..., 1:2])):
        """
        domain: ((x0, x1), (y0, y1)) describing Ω.
        true_solution: callable for the exact u(x, y); useful for UQ metrics.
        """
        self.x0, self.x1 = domain[0]
        self.y0, self.y1 = domain[1]
        self.true_solution = true_solution  # keep same attribute name convention

    # ------------------------------------------------------------------
    # Forcing term f(x,y) chosen so that u* = sin(πx) sin(πy) is exact.
    # ------------------------------------------------------------------
    def _forcing(self, xy):
        x = xy[..., 0:1]
        y = xy[..., 1:2]
        return 2 * (math.pi ** 2) * torch.sin(math.pi * x) * torch.sin(math.pi * y)

    # ------------------------------------------------------------------
    # PDE residual ‖ Δu + f ‖² on a set of interior collocation points
    # ------------------------------------------------------------------
    def residual(self, model, coloc_pt_num):
        # Uniform interior sampling
        x = torch.rand(coloc_pt_num, 1) * (self.x1 - self.x0) + self.x0
        y = torch.rand(coloc_pt_num, 1) * (self.y1 - self.y0) + self.y0
        xy = torch.cat([x, y], dim=1).to(dtype=torch.float32)
        return (self._residual(model, xy) ** 2).mean()

    def _residual(self, model, xy):
        xy = xy.requires_grad_(True)
        u = model(xy)                                      # u(x,y)
        grad_u = torch.autograd.grad(
            u, xy, grad_outputs=torch.ones_like(u), create_graph=True
        )[0]                                               # ∇u = (u_x, u_y)

        u_x = grad_u[:, 0:1]
        u_y = grad_u[:, 1:2]

        u_xx = torch.autograd.grad(
            u_x, xy, grad_outputs=torch.ones_like(u_x), create_graph=True
        )[0][:, 0:1]                                       # u_xx
        u_yy = torch.autograd.grad(
            u_y, xy, grad_outputs=torch.ones_like(u_y), create_graph=True
        )[0][:, 1:2]                                       # u_yy

        return u_xx + u_yy + self._forcing(xy)             # Δu + f(x,y)

    # ------------------------------------------------------------------
    # Dirichlet boundary loss (u ≡ 0 on ∂Ω)
    # ------------------------------------------------------------------
    def boundary_loss(self, model, n_b=500):
        # two random sets of points along each pair of opposing edges
        x = torch.rand(n_b, 1) * (self.x1 - self.x0) + self.x0
        y = torch.rand(n_b, 1) * (self.y1 - self.y0) + self.y0

        left   = torch.cat([torch.full_like(y, self.x0), y], dim=1)
        right  = torch.cat([torch.full_like(y, self.x1), y], dim=1)
        bottom = torch.cat([x, torch.full_like(x, self.y0)], dim=1)
        top    = torch.cat([x, torch.full_like(x, self.y1)], dim=1)

        xy_bdry = torch.cat([left, right, bottom, top], dim=0).to(dtype=torch.float32)
        u_pred = model(xy_bdry)
        return (u_pred ** 2).mean()
    
    # ------------------------------------------------------------------
    # Generate synthetic observations in 2-D
    # ------------------------------------------------------------------
    def data_generation(
        self,
        size: int,
        noise: float = 0.0,
        true_solution: callable = None,
        seed: int | None = None,
        device: torch.device | None = None
    ):
        """
        Draw `size` random points (x, y) inside Ω and return
        (X_train, Y_train) with optional Gaussian noise.

        Returns
        -------
        X_train : torch.Tensor  shape [size, 2]   each row = [x , y]
        Y_train : torch.Tensor  shape [size, 1]   u*(x,y) + ε
        """
        if seed is not None:
            torch.manual_seed(seed)

        if device is None:
            device = torch.device("cpu")

        # 1️⃣  Sample (x,y) uniformly from Ω
        xs = (self.x1 - self.x0) * torch.rand(size, 1, device=device) + self.x0
        ys = (self.y1 - self.y0) * torch.rand(size, 1, device=device) + self.y0
        X_train = torch.cat([xs, ys], dim=1).float()          # [size, 2]

        # 2️⃣  Evaluate the noiseless truth
        if true_solution is None:
            if hasattr(self, "true_solution") and callable(self.true_solution):
                true_solution = self.true_solution
            else:
                raise ValueError(
                    "Provide a `true_solution` callable or set `self.true_solution`."
                )
        Y_clean = true_solution(X_train)                      # [size, 1]

        # 3️⃣  Add Gaussian noise if requested
        if noise > 0.0:
            Y_train = Y_clean + noise * torch.randn_like(Y_clean)
        else:
            Y_train = Y_clean.clone()

        return X_train, Y_train
    

def plot_predictions_2D(XY_test, pred_set, true_solution, title="2D UQ Result"):
    import matplotlib.pyplot as plt
    import numpy as np

    x = XY_test[:, 0].detach().cpu().numpy()
    y = XY_test[:, 1].detach().cpu().numpy()
    lower_np = pred_set[0].detach().cpu().numpy().flatten()
    upper_np = pred_set[1].detach().cpu().numpy().flatten()
    mean_np = (lower_np + upper_np) / 2.0

    true_np = true_solution(XY_test).detach().cpu().numpy().flatten()

    fig, axs = plt.subplots(1, 3, figsize=(18, 5))
    for ax, data, title_sub in zip(
        axs,
        [true_np, mean_np, upper_np - lower_np],
        ["True u(x,y)", "Predicted Mean", "Predictive Interval Width"]
    ):
        sc = ax.tricontourf(x, y, data, levels=100)
        fig.colorbar(sc, ax=ax)
        ax.set_title(f"{title}: {title_sub}")
        ax.set_xlabel("x")
        ax.set_ylabel("y")
    plt.tight_layout()
    plt.show()

# %%
from utils_uq_vi import VIBPINN
# --------------------------------------------
# 1. Define PDE and exact solution
# --------------------------------------------
data_noise = 0.001
pde = Poisson2D()
# Generate training and testing data of the poisson function
(X_train, Y_train) = pde.data_generation(500, data_noise)
(X_test, Y_test) = pde.data_generation(100, data_noise)



# --------------------------------------------
# 2. Build DO-PINN model (input: (x,y), output: u)
# --------------------------------------------
vi_model = VIBPINN(
    pde_class=pde,
    input_dim=2,
    hidden_dims=[16, 32, 64, 64, 64, 32, 16],
    output_dim=1
)

# --------------------------------------------
# 3. Training configuration
# --------------------------------------------
loss_dict =vi_model.fit_vi_bpinn(
    coloc_pt_num=1000,
    X_train=X_train,
    Y_train=Y_train,
    λ_pde=1.0,
    λ_bc=5.0,
    λ_ic=0.0,
    epochs=20000,
    lr=3e-3,
)
# Out:
# ep     0 | L=9.71e+03 | elbo=7.96e+01 | pde=9.63e+03  ic=0.00e+00  bc=8.12e-05 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep     1 | L=1.05e+04 | elbo=8.74e+01 | pde=1.04e+04  ic=0.00e+00  bc=2.62e-04 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep   200 | L=3.18e+03 | elbo=5.01e+02 | pde=2.66e+03  ic=0.00e+00  bc=2.01e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep   400 | L=2.03e+03 | elbo=3.98e+02 | pde=1.62e+03  ic=0.00e+00  bc=1.96e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep   600 | L=1.33e+03 | elbo=2.24e+02 | pde=1.09e+03  ic=0.00e+00  bc=3.15e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep   800 | L=2.29e+03 | elbo=2.63e+02 | pde=2.01e+03  ic=0.00e+00  bc=2.30e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  1000 | L=1.41e+03 | elbo=3.10e+02 | pde=1.08e+03  ic=0.00e+00  bc=3.63e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  1200 | L=1.56e+03 | elbo=4.83e+02 | pde=1.05e+03  ic=0.00e+00  bc=4.59e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  1400 | L=1.69e+03 | elbo=3.51e+02 | pde=1.32e+03  ic=0.00e+00  bc=3.03e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  1600 | L=1.46e+03 | elbo=4.69e+02 | pde=9.77e+02  ic=0.00e+00  bc=3.23e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  1800 | L=1.38e+03 | elbo=1.08e+02 | pde=1.27e+03  ic=0.00e+00  bc=1.34e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  2000 | L=1.04e+03 | elbo=5.34e+02 | pde=4.89e+02  ic=0.00e+00  bc=3.24e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  2200 | L=1.10e+03 | elbo=3.37e+02 | pde=7.57e+02  ic=0.00e+00  bc=2.08e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  2400 | L=9.03e+02 | elbo=2.81e+02 | pde=6.08e+02  ic=0.00e+00  bc=2.79e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  2600 | L=8.55e+02 | elbo=1.22e+02 | pde=7.25e+02  ic=0.00e+00  bc=1.84e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  2800 | L=4.24e+02 | elbo=5.25e+01 | pde=3.70e+02  ic=0.00e+00  bc=3.75e-01 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  3000 | L=4.98e+03 | elbo=1.72e+02 | pde=4.81e+03  ic=0.00e+00  bc=3.35e-01 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  3200 | L=1.49e+03 | elbo=3.32e+02 | pde=1.15e+03  ic=0.00e+00  bc=1.84e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  3400 | L=1.93e+03 | elbo=4.70e+02 | pde=1.45e+03  ic=0.00e+00  bc=2.19e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  3600 | L=8.55e+02 | elbo=3.16e+02 | pde=5.31e+02  ic=0.00e+00  bc=1.68e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  3800 | L=1.06e+03 | elbo=5.96e+02 | pde=4.57e+02  ic=0.00e+00  bc=1.10e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  4000 | L=5.06e+02 | elbo=5.53e+01 | pde=4.47e+02  ic=0.00e+00  bc=6.74e-01 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  4200 | L=9.66e+01 | elbo=5.78e+01 | pde=3.85e+01  ic=0.00e+00  bc=5.09e-02 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  4400 | L=6.98e+01 | elbo=3.03e+01 | pde=3.39e+01  ic=0.00e+00  bc=1.13e+00 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  4600 | L=1.60e+02 | elbo=6.61e+01 | pde=9.31e+01  ic=0.00e+00  bc=8.44e-02 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  4800 | L=4.15e+01 | elbo=3.34e+01 | pde=7.21e+00  ic=0.00e+00  bc=1.70e-01 | lr=3.00e-03 | learned noise_std=1.000e+00
# ep  5000 | L=7.85e+01 | elbo=3.76e+01 | pde=4.04e+01  ic=0.00e+00  bc=1.00e-01 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  5200 | L=1.83e+02 | elbo=9.46e+01 | pde=8.75e+01  ic=0.00e+00  bc=1.08e-01 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  5400 | L=4.66e+01 | elbo=3.50e+01 | pde=1.13e+01  ic=0.00e+00  bc=5.74e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  5600 | L=5.12e+01 | elbo=3.89e+01 | pde=1.17e+01  ic=0.00e+00  bc=1.20e-01 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  5800 | L=1.64e+02 | elbo=2.81e+01 | pde=1.35e+02  ic=0.00e+00  bc=1.25e-01 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  6000 | L=3.32e+02 | elbo=1.91e+02 | pde=1.40e+02  ic=0.00e+00  bc=1.57e-01 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  6200 | L=2.54e+02 | elbo=2.64e+01 | pde=2.27e+02  ic=0.00e+00  bc=9.99e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  6400 | L=1.08e+02 | elbo=3.96e+01 | pde=6.81e+01  ic=0.00e+00  bc=6.37e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  6600 | L=7.42e+01 | elbo=6.09e+01 | pde=1.32e+01  ic=0.00e+00  bc=2.56e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  6800 | L=1.59e+02 | elbo=4.77e+01 | pde=1.11e+02  ic=0.00e+00  bc=3.55e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  7000 | L=1.93e+02 | elbo=3.22e+01 | pde=1.58e+02  ic=0.00e+00  bc=4.71e-01 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  7200 | L=1.23e+02 | elbo=4.03e+01 | pde=8.22e+01  ic=0.00e+00  bc=1.98e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  7400 | L=7.97e+01 | elbo=3.22e+01 | pde=4.74e+01  ic=0.00e+00  bc=2.73e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  7600 | L=5.03e+01 | elbo=3.33e+01 | pde=1.62e+01  ic=0.00e+00  bc=1.43e-01 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  7800 | L=2.06e+02 | elbo=3.09e+01 | pde=1.75e+02  ic=0.00e+00  bc=3.40e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  8000 | L=6.13e+01 | elbo=3.95e+01 | pde=2.13e+01  ic=0.00e+00  bc=1.03e-01 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  8200 | L=3.08e+02 | elbo=5.06e+01 | pde=2.57e+02  ic=0.00e+00  bc=8.29e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  8400 | L=7.02e+01 | elbo=3.79e+01 | pde=3.20e+01  ic=0.00e+00  bc=5.95e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  8600 | L=3.31e+01 | elbo=2.62e+01 | pde=6.70e+00  ic=0.00e+00  bc=3.11e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  8800 | L=4.54e+01 | elbo=3.07e+01 | pde=1.46e+01  ic=0.00e+00  bc=2.75e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  9000 | L=3.51e+01 | elbo=2.82e+01 | pde=6.70e+00  ic=0.00e+00  bc=4.73e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  9200 | L=4.61e+01 | elbo=3.35e+01 | pde=1.19e+01  ic=0.00e+00  bc=1.26e-01 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  9400 | L=7.29e+01 | elbo=2.90e+01 | pde=4.36e+01  ic=0.00e+00  bc=6.50e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  9600 | L=8.22e+01 | elbo=3.52e+01 | pde=4.69e+01  ic=0.00e+00  bc=1.36e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep  9800 | L=3.75e+01 | elbo=2.45e+01 | pde=1.27e+01  ic=0.00e+00  bc=5.11e-02 | lr=1.50e-03 | learned noise_std=1.000e+00
# ep 10000 | L=4.13e+01 | elbo=2.88e+01 | pde=1.23e+01  ic=0.00e+00  bc=3.79e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 10200 | L=3.27e+01 | elbo=2.67e+01 | pde=5.72e+00  ic=0.00e+00  bc=5.50e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 10400 | L=4.36e+01 | elbo=3.43e+01 | pde=8.96e+00  ic=0.00e+00  bc=6.01e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 10600 | L=5.07e+01 | elbo=2.63e+01 | pde=2.41e+01  ic=0.00e+00  bc=7.03e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 10800 | L=4.58e+01 | elbo=3.35e+01 | pde=1.21e+01  ic=0.00e+00  bc=3.81e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 11000 | L=5.00e+01 | elbo=3.51e+01 | pde=1.47e+01  ic=0.00e+00  bc=3.35e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 11200 | L=6.34e+01 | elbo=2.65e+01 | pde=3.64e+01  ic=0.00e+00  bc=9.91e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 11400 | L=3.59e+01 | elbo=2.57e+01 | pde=9.86e+00  ic=0.00e+00  bc=8.48e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 11600 | L=3.61e+01 | elbo=2.82e+01 | pde=7.85e+00  ic=0.00e+00  bc=1.80e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 11800 | L=3.61e+01 | elbo=2.98e+01 | pde=6.16e+00  ic=0.00e+00  bc=3.56e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 12000 | L=5.43e+01 | elbo=3.90e+01 | pde=1.52e+01  ic=0.00e+00  bc=3.57e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 12200 | L=9.64e+01 | elbo=3.69e+01 | pde=5.94e+01  ic=0.00e+00  bc=2.29e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 12400 | L=3.44e+01 | elbo=2.82e+01 | pde=5.80e+00  ic=0.00e+00  bc=6.79e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 12600 | L=5.02e+01 | elbo=3.73e+01 | pde=1.27e+01  ic=0.00e+00  bc=3.01e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 12800 | L=4.09e+01 | elbo=3.41e+01 | pde=6.50e+00  ic=0.00e+00  bc=5.05e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 13000 | L=3.28e+01 | elbo=2.63e+01 | pde=6.40e+00  ic=0.00e+00  bc=3.15e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 13200 | L=3.15e+01 | elbo=2.54e+01 | pde=5.90e+00  ic=0.00e+00  bc=4.42e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 13400 | L=3.88e+01 | elbo=3.38e+01 | pde=4.23e+00  ic=0.00e+00  bc=1.42e-01 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 13600 | L=2.97e+01 | elbo=2.70e+01 | pde=2.58e+00  ic=0.00e+00  bc=2.40e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 13800 | L=6.39e+01 | elbo=4.18e+01 | pde=2.19e+01  ic=0.00e+00  bc=5.92e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 14000 | L=3.06e+01 | elbo=2.47e+01 | pde=5.51e+00  ic=0.00e+00  bc=8.74e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 14200 | L=4.43e+01 | elbo=2.75e+01 | pde=1.62e+01  ic=0.00e+00  bc=1.20e-01 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 14400 | L=3.74e+01 | elbo=2.52e+01 | pde=1.21e+01  ic=0.00e+00  bc=2.91e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 14600 | L=4.89e+01 | elbo=4.64e+01 | pde=1.80e+00  ic=0.00e+00  bc=1.23e-01 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 14800 | L=4.50e+01 | elbo=2.70e+01 | pde=1.78e+01  ic=0.00e+00  bc=5.32e-02 | lr=7.50e-04 | learned noise_std=1.000e+00
# ep 15000 | L=3.41e+01 | elbo=2.90e+01 | pde=4.63e+00  ic=0.00e+00  bc=1.04e-01 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 15200 | L=4.31e+01 | elbo=3.69e+01 | pde=5.69e+00  ic=0.00e+00  bc=1.18e-01 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 15400 | L=2.96e+01 | elbo=2.86e+01 | pde=7.76e-01  ic=0.00e+00  bc=3.03e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 15600 | L=3.67e+01 | elbo=3.02e+01 | pde=6.33e+00  ic=0.00e+00  bc=4.18e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 15800 | L=3.59e+01 | elbo=2.90e+01 | pde=6.48e+00  ic=0.00e+00  bc=7.20e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 16000 | L=5.28e+01 | elbo=3.48e+01 | pde=1.75e+01  ic=0.00e+00  bc=1.06e-01 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 16200 | L=1.03e+02 | elbo=3.27e+01 | pde=6.98e+01  ic=0.00e+00  bc=1.57e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 16400 | L=3.59e+01 | elbo=2.52e+01 | pde=1.06e+01  ic=0.00e+00  bc=4.04e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 16600 | L=2.69e+01 | elbo=2.41e+01 | pde=2.59e+00  ic=0.00e+00  bc=4.07e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 16800 | L=4.74e+01 | elbo=2.69e+01 | pde=2.04e+01  ic=0.00e+00  bc=3.25e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 17000 | L=4.04e+01 | elbo=2.81e+01 | pde=1.22e+01  ic=0.00e+00  bc=1.98e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 17200 | L=3.64e+01 | elbo=3.17e+01 | pde=4.66e+00  ic=0.00e+00  bc=1.42e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 17400 | L=3.27e+01 | elbo=2.71e+01 | pde=5.12e+00  ic=0.00e+00  bc=9.26e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 17600 | L=7.43e+01 | elbo=2.74e+01 | pde=4.69e+01  ic=0.00e+00  bc=1.97e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 17800 | L=4.40e+01 | elbo=2.78e+01 | pde=1.60e+01  ic=0.00e+00  bc=4.99e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 18000 | L=3.57e+01 | elbo=2.76e+01 | pde=7.83e+00  ic=0.00e+00  bc=5.31e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 18200 | L=6.09e+01 | elbo=2.65e+01 | pde=3.43e+01  ic=0.00e+00  bc=3.13e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 18400 | L=3.42e+01 | elbo=2.61e+01 | pde=7.95e+00  ic=0.00e+00  bc=2.43e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 18600 | L=3.22e+01 | elbo=3.10e+01 | pde=8.60e-01  ic=0.00e+00  bc=6.45e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 18800 | L=2.50e+01 | elbo=2.45e+01 | pde=3.28e-01  ic=0.00e+00  bc=3.29e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 19000 | L=3.38e+01 | elbo=2.93e+01 | pde=4.34e+00  ic=0.00e+00  bc=3.19e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 19200 | L=2.95e+01 | elbo=2.78e+01 | pde=1.39e+00  ic=0.00e+00  bc=6.28e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 19400 | L=4.07e+01 | elbo=2.55e+01 | pde=1.51e+01  ic=0.00e+00  bc=3.03e-02 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 19600 | L=2.98e+01 | elbo=2.86e+01 | pde=7.20e-01  ic=0.00e+00  bc=1.04e-01 | lr=3.75e-04 | learned noise_std=1.000e+00
# ep 19800 | L=3.04e+01 | elbo=2.80e+01 | pde=2.25e+00  ic=0.00e+00  bc=2.73e-02 | lr=3.75e-04 | learned noise_std=1.000e+00

# %%
(X_calibration, Y_calibration) = pde.data_generation(100, data_noise)
# --------------------------------------------
# 4. Prediction: generate grid for testing
# --------------------------------------------
n_grid = 100
x = torch.linspace(0, 1, n_grid)
y = torch.linspace(0, 1, n_grid)
X, Y = torch.meshgrid(x, y, indexing='xy')
grid_test = torch.cat([X.reshape(-1, 1), Y.reshape(-1, 1)], dim=1)

# Predict with conformal UQ
pred_set = vi_model.predict(0.05, 20, grid_test, n_samples=100, z_score=1.96)  # 90% confidence
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 12
#       9 grid_test = torch.cat([X.reshape(-1, 1), Y.reshape(-1, 1)], dim=1)
#      11 # Predict with conformal UQ
# ---> 12 pred_set = vi_model.predict(0.05, 20, grid_test, n_samples=100, z_score=1.96)  # 90% confidence
#
# TypeError: VIBPINN.predict() got multiple values for argument 'n_samples'

# %%
from utils_result_viz import plot_predictions_2D
# --------------------------------------------
# 5. Visualize result
# --------------------------------------------
plot_predictions_2D(
    XY_test,
    pred_set,
    true_solution=pde.true_solution,
    title="2D Poisson CP-PINN Prediction"
)

# %%
from utils_result_metrics import cp_test_uncertainties
def generating_alphas(a_num):
    alphas = torch.linspace(0.0, 1.0, 10).view(-1, 1)
    return alphas[1:a_num-1]

alphas = generating_alphas(10)

rslt = cp_test_uncertainties(cp_model, alphas, X_test, Y_test, X_calibration, Y_calibration, X_train,
                             distance_space="feature", k=10)
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 325.35it/s]

# %%
from utils_result_viz import plot_expected_vs_empirical
plot_expected_vs_empirical(rslt)

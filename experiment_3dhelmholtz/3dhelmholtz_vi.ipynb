# %%
# Basic
import torch
import math
import torch.nn as nn
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau
import numpy as np
from numpy import random
torch.set_num_threads(4)

# PDEi
from utils_pde.utils_pde_2dpoisson import Poisson2D

# Viz
from utils_tools.utils_result_viz import plot_predictions_2D

# Base Mdoels
from utils_uqmd.utils_uq_dropout import DropoutPINN
from utils_uqmd.utils_uq_mlp import MLPPINN
from utils_uqmd.utils_uq_vi import VIBPINN

# CP
from utils_uqmd.utils_uq_cp import CP

# Ensure reproducibility
import random, numpy as np, torch
seed = 12345
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(seed)

# ----------------------------------------------------------------------
# Data Noise
data_noise = 0.05          # same as your 2-D example


# Define the 3-D Helmholtz PDE
from utils_pde.utils_pde_3dhelmholtz import Helmholtz3D
domain = ((0.0, 1.0), (0.0, 1.0), (0.0, 1.0))   # (x0,x1),(y0,y1),(z0,z1)
k = math.pi                                     # wave number

true_solution = (
    lambda xyz: torch.sin(math.pi * xyz[..., 0:1])
              * torch.sin(math.pi * xyz[..., 1:2])
              * torch.sin(math.pi * xyz[..., 2:3])
)

pde = Helmholtz3D(k=k, domain=domain, true_solution=true_solution)

# Generate training / testing / calibration data
(X_train, Y_train)         = pde.data_generation(1_000, data_noise)
(X_test,  Y_test)          = pde.data_generation(   200, data_noise)
(X_calibration, Y_calibration) = pde.data_generation(400, data_noise)

# Number of interior collocation points for the PINN residual
colloc_pt_num = 200

# ----------------------------------------------------------------------


# Generating alphas to test
from utils_tools.utils_result_metrics import generating_alphas
alphas = generating_alphas(20)

# ----------------------------------------------------------------------

# Build base model
vi_pinn = VIBPINN(
    pde_class=pde, 
    input_dim=3,
    hidden_dims=[32, 64, 128, 128, 128, 64, 32], 
    output_dim=1, 
)

# Define tuning arguments
# Base Model
fit_args = {
    "coloc_pt_num":colloc_pt_num,
    "X_train":X_train, 
    "Y_train":Y_train
}

# Change the parameter grids to test
fit_kwargs_grid = {
    "epochs":[200],
    "λ_pde":[3.0, 5.0], "λ_bc":[5.0, 10.0], "λ_elbo":[1.0, 2.0, 5.0],  # Change based on baseline model
    "lr":[1e-3, 3e-4],
    # "scheduler_cls":[StepLR], "scheduler_kwargs":[{'step_size': 5000, 'gamma': 0.5}],
    "stop_schedule":[10000, 20000, 40000]
}

baseline_pred_kwargs = {  # Change all the kwargs here
    "n_samples":10
}


# CP Model
cp_pred_kwargs = {
        "X_train":X_train,  "Y_train":Y_train,
        "X_cal":X_calibration, "Y_cal":Y_calibration,
        "heuristic_u":"raw_std",
        "k":10
}

cp_testing_args = {
    "alphas":alphas, 
    "X_test":X_test, "Y_test":Y_test, 
    "X_cal":X_calibration, "Y_cal":Y_calibration, "X_train":X_train, "Y_train":Y_train, 
    "heuristic_u":"raw_std", # Change base on if the baseline model has its original uq band
    "k":10
}

baseline_testing_args = { 
    "uqmodel":vi_pinn,   # Change this
    "alphas":alphas, 
    "X_test":X_test, "Y_test":Y_test
}

# Defining testing grid
# --------------------------------------------
# Defining Plotting Grid
# --------------------------------------------

n_grid = 20
x = torch.linspace(domain[0][0], domain[0][1], n_grid)
y = torch.linspace(domain[1][0], domain[1][1], n_grid)
z = torch.linspace(domain[2][0], domain[2][1], n_grid)
X, Y, Z = torch.meshgrid(x, y, z, indexing='xy')
grid_test = torch.cat([X.reshape(-1, 1), Y.reshape(-1, 1), Z.reshape(-1, 1)], dim=1)

# ----------------------------------------------------------------------

# Start hyperparameter tuning 
from utils_tools.utils_tuning import hyperparameter_tuning
from utils_tools.utils_result_viz import plot_2D_comparison_with_coverage, plot_metrics_table
from utils_uqmd.utils_uq_cp import CP
from utils_tools.utils_result_metrics import cp_test_uncertainties, vi_test_uncertainties, do_test_uncertainties

hyperparameter_tuning(
    plot_title="VI CP Model", # Change this
    # Model Fitting & Predicting
    uqmodel=vi_pinn,  # Change this
    alpha=0.05, 
    X_test=grid_test, Y_test=Y_test, 
    fit_args=fit_args, fit_kwargs_grid=fit_kwargs_grid, baseline_pred_kwargs=baseline_pred_kwargs, cp_pred_kwargs=cp_pred_kwargs, 
    true_solution=pde.true_solution,
    # Coverage Test
    baseline_testing_args=baseline_testing_args, cp_testing_args=cp_testing_args,
    baseline_test_uncertainties=vi_test_uncertainties, # Change this
    # Plotting function
    plotting_func=plot_metrics_table,
    save_dir="3dhelmholtz_vi",  # Change this
    X_validation=X_test, Y_validation=Y_test
)
# Out:
# Using device: cpu
# Using device: cpu
#
# [🔎] Trying: {'epochs': 200, 'λ_pde': 3.0, 'λ_bc': 5.0, 'λ_elbo': 1.0, 'lr': 0.001, 'stop_schedule': 10000}
#
# [🟠] Training...
# ep     0 | L=7.92e+03 | elbo=1.70e+02 | pde=2.58e+03  ic=0.00e+00  bc=3.35e-03 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep     1 | L=6.94e+03 | elbo=1.91e+02 | pde=2.25e+03  ic=0.00e+00  bc=1.31e-03 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep     2 | L=6.79e+03 | elbo=1.73e+02 | pde=2.21e+03  ic=0.00e+00  bc=3.08e-03 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep     4 | L=7.07e+03 | elbo=1.91e+02 | pde=2.29e+03  ic=0.00e+00  bc=8.66e-04 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep     6 | L=3.43e+03 | elbo=1.80e+02 | pde=1.08e+03  ic=0.00e+00  bc=3.94e-03 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep     8 | L=9.80e+03 | elbo=1.75e+02 | pde=3.21e+03  ic=0.00e+00  bc=6.62e-06 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    10 | L=5.29e+03 | elbo=1.94e+02 | pde=1.70e+03  ic=0.00e+00  bc=2.21e-03 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    12 | L=8.34e+03 | elbo=1.92e+02 | pde=2.72e+03  ic=0.00e+00  bc=2.39e-03 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    14 | L=6.40e+03 | elbo=2.01e+02 | pde=2.06e+03  ic=0.00e+00  bc=5.30e-04 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    16 | L=6.11e+03 | elbo=2.00e+02 | pde=1.97e+03  ic=0.00e+00  bc=3.24e-03 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    18 | L=4.60e+03 | elbo=1.92e+02 | pde=1.47e+03  ic=0.00e+00  bc=1.02e-03 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    20 | L=7.15e+03 | elbo=1.76e+02 | pde=2.33e+03  ic=0.00e+00  bc=3.26e-04 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    22 | L=1.08e+04 | elbo=1.78e+02 | pde=3.54e+03  ic=0.00e+00  bc=4.47e-03 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    24 | L=3.75e+03 | elbo=1.92e+02 | pde=1.19e+03  ic=0.00e+00  bc=2.35e-03 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep
-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   194 | L=2.55e+03 | elbo=5.09e+02 | pde=6.80e+02  ic=0.00e+00  bc=1.61e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   196 | L=1.71e+03 | elbo=4.76e+02 | pde=4.11e+02  ic=0.00e+00  bc=2.66e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   198 | L=1.95e+03 | elbo=4.17e+02 | pde=5.12e+02  ic=0.00e+00  bc=5.18e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
#
# [🟠] Base Model Inferencing...
#
# [🟠] CP Model Inferencing...
#
# [🟠] Computing Coverage...
# 100%|██████████| 19/19 [00:02<00:00,  7.72it/s]
# 100%|██████████| 19/19 [04:28<00:00, 14.13s/it]
# [✅] Data Loss = 4.807e-01
#
# [🔎] Trying: {'epochs': 200, 'λ_pde': 3.0, 'λ_bc': 5.0, 'λ_elbo': 1.0, 'lr': 0.001, 'stop_schedule': 20000}
#
# [🟠] Training...
# ep     0 | L=2.27e+03 | elbo=4.01e+02 | pde=6.21e+02  ic=0.00e+00  bc=2.64e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep     1 | L=2.55e+03 | elbo=3.58e+02 | pde=7.29e+02  ic=0.00e+00  bc=1.39e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep     2 | L=2.61e+03 | elbo=4.28e+02 | pde=7.28e+02  ic=0.00e+00  bc=3.21e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep     4 | L=1.91e+03 | elbo=4.08e+02 | pde=5.01e+02  ic=0.00e+00  bc=2.24e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep     6 | L=1.56e+03 | elbo=3.67e+02 | pde=3.98e+02  ic=0.00e+00  bc=2.70e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep     8 | L=1.92e+03 | elbo=3.31e+02 | pde=5.29e+02  ic=0.00e+00  bc=9.22e-02 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    10 | L=1.72e+03 | elbo=4.40e+02 | pde=4.28e+02  ic=0.00e+00  bc=1.65e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    12 | L=2.35e+03 | elbo=3.37e+02 | pde=6.72e+02  ic=0.00e+00  bc=1.94e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    14 | L=1.70e+03 | elbo=3.10e+02 | pde=4.63e+02  ic=0.00e+00  bc=8.22e-02 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    16 | L=3.36e+03 | elbo=3.34e+02 | pde=1.01e+03  ic=0.00e+00  bc=1.51e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    18 | L=1.57e+03 | elbo=3.02e+02 | pde=4.21e+02  ic=0.00e+00  bc=1.44e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    20 | L=1.89e+03 | elbo=4.74e+02 | pde=4.71e+02  ic=0.00e+00  bc=2.93e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    22 | L=2.32e+03 | elbo=4.38e+02 | pde=6.26e+02  ic=0.00e+00  bc=2.18e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    24 | L=2.70e+03 | elbo=3.95e+02 | pde=7.67e+02  ic=0.00e+00  bc=1.57e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    26 | L=1.82e+03 | elbo=3.82e+02 | pde=4.80e+02  ic=0.00e+00  bc=2.92e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    28 | L=2.64e+03 | elbo=4.41e+02 | pde=7.33e+02  ic=0.00e+00  bc=1.97e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    30 | L=2.25e+03 | elbo=4.54e+02 | pde=5.98e+02  ic=0.00e+00  bc=1.66e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    32 | L=2.05e+03 | elbo=4.49e+02 | pde=5.33e+02  ic=0.00e+00  bc=2.27e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    34 | L=3.10e+03 | elbo=3.01e+02 | pde=9.32e+02  ic=0.00e+00  bc=1.89e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep    36 | L=1.55e+03 | elbo=3.31e+02 | pde=4.06e+02  ic=0.00e+00  bc=3.02e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep
-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   152 | L=1.77e+03 | elbo=4.40e+02 | pde=4.43e+02  ic=0.00e+00  bc=3.30e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   154 | L=2.15e+03 | elbo=4.46e+02 | pde=5.68e+02  ic=0.00e+00  bc=2.92e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   156 | L=2.15e+03 | elbo=3.60e+02 | pde=5.95e+02  ic=0.00e+00  bc=2.06e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   158 | L=2.33e+03 | elbo=3.52e+02 | pde=6.60e+02  ic=0.00e+00  bc=1.17e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   160 | L=1.65e+03 | elbo=2.97e+02 | pde=4.51e+02  ic=0.00e+00  bc=2.12e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   162 | L=1.67e+03 | elbo=3.47e+02 | pde=4.41e+02  ic=0.00e+00  bc=2.23e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   164 | L=1.91e+03 | elbo=4.96e+02 | pde=4.71e+02  ic=0.00e+00  bc=1.67e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   166 | L=2.83e+03 | elbo=3.15e+02 | pde=8.39e+02  ic=0.00e+00  bc=2.80e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   168 | L=1.78e+03 | elbo=4.04e+02 | pde=4.59e+02  ic=0.00e+00  bc=2.22e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   170 | L=1.76e+03 | elbo=4.63e+02 | pde=4.30e+02  ic=0.00e+00  bc=2.51e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   172 | L=1.62e+03 | elbo=5.63e+02 | pde=3.50e+02  ic=0.00e+00  bc=2.81e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   174 | L=2.12e+03 | elbo=4.50e+02 | pde=5.56e+02  ic=0.00e+00  bc=5.02e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   176 | L=2.25e+03 | elbo=3.35e+02 | pde=6.36e+02  ic=0.00e+00  bc=3.53e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   178 | L=2.16e+03 | elbo=3.77e+02 | pde=5.95e+02  ic=0.00e+00  bc=4.05e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   180 | L=2.29e+03 | elbo=5.71e+02 | pde=5.73e+02  ic=0.00e+00  bc=2.27e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   182 | L=2.21e+03 | elbo=3.61e+02 | pde=6.17e+02  ic=0.00e+00  bc=3.37e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   184 | L=2.70e+03 | elbo=4.63e+02 | pde=7.46e+02  ic=0.00e+00  bc=3.12e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   186 | L=1.58e+03 | elbo=3.93e+02 | pde=3.95e+02  ic=0.00e+00  bc=7.86e-02 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   188 | L=1.99e+03 | elbo=4.45e+02 | pde=5.16e+02  ic=0.00e+00  bc=1.86e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   190 | L=2.17e+03 | elbo=3.87e+02 | pde=5.95e+02  ic=0.00e+00  bc=1.99e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   192 | L=2.11e+03 | elbo=4.98e+02 | pde=5.36e+02  ic=0.00e+00  bc=1.65e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   194 | L=2.34e+03 | elbo=4.20e+02 | pde=6.39e+02  ic=0.00e+00  bc=2.26e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   196 | L=2.66e+03 | elbo=4.74e+02 | pde=7.28e+02  ic=0.00e+00  bc=2.19e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   198 | L=1.99e+03 | elbo=4.76e+02 | pde=5.04e+02  ic=0.00e+00  bc=4.54e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
#
# [🟠] Base Model Inferencing...
#
# [🟠] CP Model Inferencing...
#
# [🟠] Computing Coverage...
# 100%|██████████| 19/19 [00:02<00:00,  7.51it/s]
# 100%|██████████| 19/19 [04:35<00:00, 14.47s/it]
# [✅] Data Loss = 5.912e-01
#
# [🔎] Trying: {'epochs': 200, 'λ_pde': 3.0, 'λ_bc': 5.0, 'λ_elbo': 1.0, 'lr': 0.001, 'stop_schedule': 40000}
#
# [🟠] Training...
# ep     0 | L=2.11e+03 | elbo=3.86e+02 | pde=5.74e+02  ic=0.00e+00  bc=2.85e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep
-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   166 | L=2.54e+03 | elbo=3.13e+02 | pde=7.41e+02  ic=0.00e+00  bc=2.45e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   168 | L=1.73e+03 | elbo=4.13e+02 | pde=4.39e+02  ic=0.00e+00  bc=1.85e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   170 | L=1.71e+03 | elbo=4.24e+02 | pde=4.27e+02  ic=0.00e+00  bc=2.37e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   172 | L=1.50e+03 | elbo=4.54e+02 | pde=3.50e+02  ic=0.00e+00  bc=2.43e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   174 | L=2.05e+03 | elbo=4.02e+02 | pde=5.48e+02  ic=0.00e+00  bc=4.39e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   176 | L=2.25e+03 | elbo=3.35e+02 | pde=6.38e+02  ic=0.00e+00  bc=3.19e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   178 | L=2.15e+03 | elbo=3.59e+02 | pde=5.95e+02  ic=0.00e+00  bc=3.90e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   180 | L=2.23e+03 | elbo=5.14e+02 | pde=5.72e+02  ic=0.00e+00  bc=2.28e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   182 | L=2.18e+03 | elbo=3.47e+02 | pde=6.12e+02  ic=0.00e+00  bc=3.39e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   184 | L=2.56e+03 | elbo=4.62e+02 | pde=7.00e+02  ic=0.00e+00  bc=3.55e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   186 | L=1.55e+03 | elbo=4.09e+02 | pde=3.80e+02  ic=0.00e+00  bc=8.92e-02 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   188 | L=2.04e+03 | elbo=4.50e+02 | pde=5.30e+02  ic=0.00e+00  bc=1.83e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   190 | L=2.09e+03 | elbo=3.85e+02 | pde=5.68e+02  ic=0.00e+00  bc=2.10e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   192 | L=2.09e+03 | elbo=4.76e+02 | pde=5.37e+02  ic=0.00e+00  bc=1.52e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   194 | L=2.26e+03 | elbo=4.22e+02 | pde=6.13e+02  ic=0.00e+00  bc=2.18e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   196 | L=2.39e+03 | elbo=4.66e+02 | pde=6.41e+02  ic=0.00e+00  bc=2.04e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   198 | L=2.02e+03 | elbo=4.73e+02 | pde=5.15e+02  ic=0.00e+00  bc=4.67e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
#
# [🟠] Base Model Inferencing...
#
# [🟠] CP Model Inferencing...
#
# [🟠] Computing Coverage...
# 100%|██████████| 19/19 [00:02<00:00,  6.33it/s]
# 100%|██████████| 19/19 [04:44<00:00, 15.00s/it]
# [✅] Data Loss = 5.787e-01
#
# [🔎] Trying: {'epochs': 200, 'λ_pde': 3.0, 'λ_bc': 5.0, 'λ_elbo': 1.0, 'lr': 0.0003, 'stop_schedule': 10000}
#
# [🟠] Training...
# ep     0 | L=2.18e+03 | elbo=3.82e+02 | pde=6.00e+02  ic=0.00e+00  bc=2.82e-01 | lr=3.00e-04 | learned noise_std=1.000e+00
# ep     1 | L=2.67e+03 | elbo=3.30e+02 | pde=7.79e+02  ic=0.00e+00  bc=1.26e-01 | lr=3.00e-04 | learned noise_std=1.000e+00
# ep     2 | L=2.17e+03 | elbo=3.76e+02 | pde=5.98e+02  ic=0.00e+00  bc=3.64e-01 | lr=3.00e-04 | learned noise_std=1.000e+00
# ep     4 | L=1.79e+03 | elbo=3.90e+02 | pde=4.67e+02  ic=0.00e+00  bc=2.51e-01 | lr=3.00e-04 | learned noise_std=1.000e+00
# ep     6 | L=1.58e+03 | elbo=3.71e+02 | pde=4.01e+02  ic=0.00e+00  bc=3.43e-01 | lr=3.00e-04 | learned noise_std=1.000e+00
# ep     8 | L=1.77e+03 | elbo=3.15e+02 | pde=4.85e+02  ic=0.00e+00  bc=1.07e-01 | lr=3.00e-04 | learned noise_std=1.000e+00
# ep
-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   156 | L=2.24e+03 | elbo=2.25e+02 | pde=5.95e+02  ic=0.00e+00  bc=2.30e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   158 | L=2.32e+03 | elbo=2.94e+02 | pde=5.76e+02  ic=0.00e+00  bc=4.73e-02 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   160 | L=1.48e+03 | elbo=2.02e+02 | pde=3.57e+02  ic=0.00e+00  bc=2.73e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   162 | L=1.62e+03 | elbo=2.49e+02 | pde=3.73e+02  ic=0.00e+00  bc=1.30e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   164 | L=1.76e+03 | elbo=2.89e+02 | pde=3.94e+02  ic=0.00e+00  bc=1.08e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   166 | L=2.85e+03 | elbo=2.81e+02 | pde=7.62e+02  ic=0.00e+00  bc=9.14e-02 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   168 | L=1.98e+03 | elbo=3.40e+02 | pde=4.32e+02  ic=0.00e+00  bc=5.13e-02 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   170 | L=1.82e+03 | elbo=2.59e+02 | pde=4.33e+02  ic=0.00e+00  bc=1.39e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   172 | L=1.50e+03 | elbo=2.02e+02 | pde=3.65e+02  ic=0.00e+00  bc=2.48e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   174 | L=2.32e+03 | elbo=3.42e+02 | pde=5.44e+02  ic=0.00e+00  bc=1.95e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   176 | L=2.56e+03 | elbo=2.58e+02 | pde=6.80e+02  ic=0.00e+00  bc=1.45e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   178 | L=2.21e+03 | elbo=2.02e+02 | pde=6.03e+02  ic=0.00e+00  bc=2.40e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   180 | L=2.50e+03 | elbo=3.92e+02 | pde=5.72e+02  ic=0.00e+00  bc=7.81e-02 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   182 | L=2.38e+03 | elbo=2.81e+02 | pde=6.06e+02  ic=0.00e+00  bc=3.06e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   184 | L=2.88e+03 | elbo=3.78e+02 | pde=7.06e+02  ic=0.00e+00  bc=4.57e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   186 | L=1.72e+03 | elbo=2.57e+02 | pde=4.02e+02  ic=0.00e+00  bc=1.07e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   188 | L=2.12e+03 | elbo=2.59e+02 | pde=5.35e+02  ic=0.00e+00  bc=1.25e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   190 | L=2.41e+03 | elbo=3.02e+02 | pde=6.03e+02  ic=0.00e+00  bc=2.16e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   192 | L=2.88e+03 | elbo=4.85e+02 | pde=6.38e+02  ic=0.00e+00  bc=1.01e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   194 | L=2.80e+03 | elbo=3.85e+02 | pde=6.76e+02  ic=0.00e+00  bc=2.41e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   196 | L=2.40e+03 | elbo=3.45e+02 | pde=5.70e+02  ic=0.00e+00  bc=2.28e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
# ep   198 | L=2.36e+03 | elbo=4.26e+02 | pde=5.02e+02  ic=0.00e+00  bc=6.95e-01 | lr=1.00e-03 | learned noise_std=1.000e+00
#
# [🟠] Base Model Inferencing...
#
# [🟠] CP Model Inferencing...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 140
#     137 from utils_uqmd.utils_uq_cp import CP
#     138 from utils_tools.utils_result_metrics import cp_test_uncertainties, vi_test_uncertainties, do_test_uncertainties
# --> 140 hyperparameter_tuning(
#     141     plot_title="VI CP Model", # Change this
#     142     # Model Fitting & Predicting
#     143     uqmodel=vi_pinn,  # Change this
#     144     alpha=0.05,
#     145     X_test=grid_test, Y_test=Y_test,
#     146     fit_args=fit_args, fit_kwargs_grid=fit_kwargs_grid, baseline_pred_kwargs=baseline_pred_kwargs, cp_pred_kwargs=cp_pred_kwargs,
#     147     true_solution=pde.true_solution,
#     148     # Coverage Test
#     149     baseline_testing_args=baseline_testing_args, cp_testing_args=cp_testing_args,
#     150     baseline_test_uncertainties=vi_test_uncertainties, # Change this
#     151     # Plotting function
#     152     plotting_func=plot_metrics_table,
#     153     save_dir="3dhelmholtz_vi",  # Change this
#     154     X_validation=X_test, Y_validation=Y_test
#     155 )
#
# File ~/Desktop/PINN UQ/utils_tools/utils_tuning.py:120, in hyperparameter_tuning(plot_title, uqmodel, alpha, X_test, Y_test, fit_args, fit_kwargs_grid, baseline_pred_kwargs, cp_pred_kwargs, true_solution, baseline_testing_args, cp_testing_args, baseline_test_uncertainties, plotting_func, save_dir, X_vis, Y_vis, X_validation, Y_validation)
#     118 cp_model = CP(uqmodel)
#     119 # CP+ Model Prediction
# --> 120 cp_cal_predset = cp_model.predict(
#     121     alpha=alpha, X_test=X_test,
#     122     **cp_pred_kwargs
#     123 )
#     125 # Compute the metrics and coverage plots
#     126 print(f"\n[🟠] Computing Coverage...")
#
# File ~/Desktop/PINN UQ/utils_uqmd/utils_uq_cp.py:122, in CP.predict(self, alpha, X_test, X_train, Y_train, X_cal, Y_cal, heuristic_u, k)
#     120 elif heuristic_u == "raw_std":
#     121     cal_scores = self._conf_metric_rawstd(alpha, X_cal, Y_cal, X_train)
# --> 122     test_u     = self._rawstd(alpha, X_test)
#     123 else:
#     124     raise ValueError("heuristic_u must be 'feature', 'latent' or 'raw_std'")
#
# File ~/Desktop/PINN UQ/utils_uqmd/utils_uq_cp.py:59, in CP._rawstd(self, alpha, X)
#      57 """Return (upper-lower) from the model’s own `predict` method."""
#      58 self.model.eval()
# ---> 59 pred_set = self.model.predict(alpha, X)
#      60 width = (pred_set[1] - pred_set[0]).squeeze(-1)    # (N,)
#      61 return _to_numpy(width)
#
# File ~/Desktop/PINN UQ/utils_uqmd/utils_uq_vi.py:136, in VIBPINN.predict(self, alpha, X_test, n_samples)
#     134 preds = []
#     135 for _ in range(n_samples):
# --> 136     y_pred = self.forward(X_test)
#     137     preds.append(y_pred.detach())
#     138 preds = torch.stack(preds)
#
# File ~/Desktop/PINN UQ/utils_uqmd/utils_model_bpinn.py:34, in BayesianFeedForwardNN.forward(self, x, sample)
#      31 out = x
#      32 for layer in self.layers:
#      33     # [BL, act, BL, act, ..., act, BL] go through all the layers
# ---> 34     out = layer(out)  # BayesianLinear or activation
#      35 return out
#
# File ~/miniconda3/envs/cp/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/cp/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Desktop/PINN UQ/utils_uqmd/utils_layer_BayesianLinearLayer.py:59, in BayesianLinearLayer.forward(self, x, sample)
#      57 else:                       # posterior mean
#      58     weight, bias = self.weight_mu, self.bias_mu
# ---> 59 return x.matmul(weight.t()) + bias
#
# File ~/miniconda3/envs/cp/lib/python3.10/site-packages/torch/utils/_device.py:104, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#     102 if func in _device_constructors() and kwargs.get('device') is None:
#     103     kwargs['device'] = self.device
# --> 104 return func(*args, **kwargs)
#
# KeyboardInterrupt:

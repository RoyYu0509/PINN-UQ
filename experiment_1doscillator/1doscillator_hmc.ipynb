# %%
# ────────────────────────────────────────────────────────────────────────────────
# 0. Imports & reproducibility
# ────────────────────────────────────────────────────────────────────────────────
import math, random, numpy as np, torch
from torch import nn
from torch.optim.lr_scheduler import StepLR

torch.set_num_threads(4)
seed = 12345
random.seed(seed); np.random.seed(seed); torch.manual_seed(seed)
if torch.cuda.is_available(): torch.cuda.manual_seed_all(seed)

# ────────────────────────────────────────────────────────────────────────────────
# 1. Ground-truth PDE setup 
# ────────────────────────────────────────────────────────────────────────────────
from utils_pde.utils_pde_damposcillation import DampedOscillator1D  

ζ      = 0.05                       # damping ratio
ω      = 2 * math.pi * 0.5          # natural frequency (1 Hz)
ω_d    = ω * math.sqrt(1 - ζ**2)    # damped natural frequency
u0, v0 = 1.0, 0.0                   # initial displacement & velocity

forcing_func  = lambda t: 0.0 * t   # zero external force

true_solution = lambda t: (
    np.exp(-ζ * ω * t) *
    (u0 * np.cos(ω_d * t) + (v0 + ζ * ω * u0) / ω_d * np.sin(ω_d * t))
)

domain = (0.0, 5.0)                 # simulate 10 s

pde = DampedOscillator1D(
    zeta=ζ, omega=ω, forcing_func=forcing_func,
    init_cond=(u0, v0), domain=domain, true_solution=true_solution
)

# ────────────────────────────────────────────────────────────────────────────────
# 3. Training / calibration / test data
# ────────────────────────────────────────────────────────────────────────────────
x_colloc_num = 50

data_noise = 0.05
(X_train, Y_train)         = pde.data_generation(300, data_noise)
(X_test, Y_test)           = pde.data_generation(100, data_noise)
(X_calibration, Y_calibration) = pde.data_generation(100, data_noise)


# Collocation points in (0,5)
x_collocation = torch.linspace(*domain, steps=x_colloc_num).view(-1, 1)
x_collocation = x_collocation[(x_collocation > domain[0]) & (x_collocation < domain[1])].view(-1, 1)

# Dense grid for nice plotting
grid_test = torch.linspace(*domain, 800).unsqueeze(1)

# Visualize the graph
from utils_tools.utils_result_viz import plot_truth_and_samples_1D
plot_truth_and_samples_1D(
    *domain,
    X_train   = X_train,
    Y_train   = Y_train,
    true_solution=true_solution,
    x_colloc = x_collocation,
    title     = "Underdamped oscillator: ground-truth vs noisy data"
)

# %%
# ────────────────────────────────────────────────────────────────────────────────
# 4. Build HMC-BPINN (1 input → 1 output)
# ────────────────────────────────────────────────────────────────────────────────
from utils_uqmd.utils_uq_hmc import HMCBPINN

model_args = {
    "pde_class":pde,
    "input_dim":1,
    "hidden_dims":[32, 32, 32, 32],
    "output_dim":1,
    "prior_std":0.5
}

# Model
hmc_model = HMCBPINN(
    **model_args
)


# ────────────────────────────────────────────────────────────────────────────────
# 5. Hyper-parameter grid & CP settings
# ────────────────────────────────────────────────────────────────────────────────
fit_args = dict(coloc_pt_num=200, X_train=X_train, Y_train=Y_train)
fit_kwargs_grid = dict(
    epochs=[20000],
    λ_pde=[1.0, 3.50, 5.0], λ_ic=[5.0, 10.0, 15.0], λ_data=[5.0, 2.5, 1.0],
    hmc_samples=[30000],
    burn_in = [5000],
    step_size = [1e-4],
    leapfrog_steps = [15],
    lr=[1e-3], stop_schedule=[20000]
)

baseline_pred_kwargs = dict(n_samples=000)

# Conformal-prediction settings
alphas = torch.linspace(0.01, 0.99, 20)

from utils_uqmd.utils_uq_cp import CP

# CP Model
cp_pred_kwargs = {
        "X_train":X_train,  "Y_train":Y_train,
        "X_cal":X_calibration, "Y_cal":Y_calibration,
        "heuristic_u":"raw_std",
        "k":10
}

cp_coverage_args = {
    "alphas":alphas, 
    "X_test":X_test, "Y_test":Y_test, 
    "X_cal":X_calibration, "Y_cal":Y_calibration, "X_train":X_train, "Y_train":Y_train, 
    "heuristic_u":"raw_std", # Change base on if the baseline model has its original uq band
    "k":10
}

baseline_coverage_args = { 
    # "uqmodel":hmc_model
    "alphas":alphas, 
    "X_test":X_test, "Y_test":Y_test,
    "n_samples":5000
}


# ────────────────────────────────────────────────────────────────────────────────
# 6. Launch tuning with the NEW 1-D coverage plot
# ────────────────────────────────────────────────────────────────────────────────
from utils_tools.utils_tuning       import hyperparameter_tuning
from utils_tools.utils_result_viz   import plot_1D_comparison_with_coverage
from utils_tools.utils_result_metrics import (
    do_test_uncertainties, cp_test_uncertainties, hmc_test_uncertainties
)


hyperparameter_tuning(
    plot_title="Dopout CP Model", # Change this
    # Model Fitting & Predicting
    uqmodel=hmc_model,  # Change this|
    alpha=0.05, 
    X_test=grid_test, Y_test=Y_test, 
    fit_args=fit_args, fit_kwargs_grid=fit_kwargs_grid, baseline_pred_kwargs=baseline_pred_kwargs, cp_pred_kwargs=cp_pred_kwargs, 
    true_solution=pde.true_solution,
    # Coverage Test
    baseline_testing_args=baseline_coverage_args, cp_testing_args=cp_coverage_args,
    baseline_test_uncertainties=hmc_test_uncertainties, # Change this
    # Plotting function
    plotting_func=plot_1D_comparison_with_coverage, # Change this
    save_dir="1doscil_hmc_cp", # Change this
    X_vis=X_train, Y_vis=Y_train,
    X_validation=X_train, Y_validation=Y_train
)
# Out:
# [🔎] Trying: {'epochs': 1000, 'λ_pde': 3.5, 'λ_ic': 5.0, 'λ_data': 1.0, 'hmc_samples': 10000, 'burn_in': 5000, 'step_size': 0.0001, 'leapfrog_steps': 15, 'lr': 0.009, 'stop_schedule': 20000}
#
# [🟠] Training...
# MAP:  54%|█████▎    | 535/1000 [00:01<00:01, 307.02it/s, loss=2.56e-01]
# [MAP] epoch    500 −logPost=2.564e-01  Data=2.56e-01  PDE=6.53e-06  IC=9.99e-01  BC=0.00e+00
# [MAP] epoch   1000 −logPost=2.564e-01  Data=2.56e-01  PDE=6.53e-06  IC=9.99e-01  BC=0.00e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 75
#      69 from utils_tools.utils_result_viz   import plot_1D_comparison_with_coverage
#      70 from utils_tools.utils_result_metrics import (
#      71     do_test_uncertainties, cp_test_uncertainties, hmc_test_uncertainties
#      72 )
# ---> 75 hyperparameter_tuning(
#      76     plot_title="Dopout CP Model", # Change this
#      77     # Model Fitting & Predicting
#      78     uqmodel=hmc_model,  # Change this|
#      79     alpha=0.05,
#      80     X_test=grid_test, Y_test=Y_test,
#      81     fit_args=fit_args, fit_kwargs_grid=fit_kwargs_grid, baseline_pred_kwargs=baseline_pred_kwargs, cp_pred_kwargs=cp_pred_kwargs,
#      82     true_solution=pde.true_solution,
#      83     # Coverage Test
#      84     baseline_testing_args=baseline_coverage_args, cp_testing_args=cp_coverage_args,
#      85     baseline_test_uncertainties=hmc_test_uncertainties, # Change this
#      86     # Plotting function
#      87     plotting_func=plot_1D_comparison_with_coverage, # Change this
#      88     save_dir="1doscil_hmc_cp", # Change this
#      89     X_vis=X_train, Y_vis=Y_train,
#      90     X_validation=X_train, Y_validation=Y_train
#      91 )
#
# File ~/Desktop/PINN UQ/utils_tools/utils_tuning.py:115, in hyperparameter_tuning(plot_title, uqmodel, alpha, X_test, Y_test, fit_args, fit_kwargs_grid, baseline_pred_kwargs, cp_pred_kwargs, true_solution, baseline_testing_args, cp_testing_args, baseline_test_uncertainties, plotting_func, save_dir, X_vis, Y_vis, X_validation, Y_validation)
#     113 # Baseline Model
#     114 print(f"\n[🟠] Training...")
# --> 115 baseline_loss_dict = uqmodel.fit(**fit_args, **hyperparams)
#     117 # Compute the baseline model's data loss
#     118 if (X_validation is None) or (Y_validation is None):
#
# File ~/Desktop/PINN UQ/utils_uqmd/utils_uq_hmc.py:178, in HMCBPINN.fit(self, coloc_pt_num, X_train, Y_train, lam_pde, lam_ic, lam_bc, lam_data, epochs, lr, hmc_samples, burn_in, print_every, step_size, leapfrog_steps, lr_decay_step, lr_decay_gamma, **unused)
#     176 for lf in range(self.L):
#     177     θ_prop = θ_prop + self.eps * p
# --> 178     U_prop, g = potential_and_grad(θ_prop)
#     179     if lf != self.L - 1:
#     180         p = p - self.eps * g
#
# File ~/Desktop/PINN UQ/utils_uqmd/utils_uq_hmc.py:154, in HMCBPINN.fit.<locals>.potential_and_grad(theta_mat)
#     152     if p.grad is not None:
#     153         p.grad.zero_()
# --> 154 U.backward()
#     155 g = flatten_params(p.grad for p in self.parameters())
#     157 U_vals.append(U.detach())
#
# File ~/miniconda3/envs/cp/lib/python3.10/site-packages/torch/_tensor.py:639, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     595 r"""Computes the gradient of current tensor wrt graph leaves.
#     596
#     597 The graph is differentiated using the chain rule. If the tensor is
#    (...)
#     636         used to compute the :attr:`tensors`.
#     637 """
#     638 if has_torch_function_unary(self):
# --> 639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#     642         self,
#     643         gradient=gradient,
#     644         retain_graph=retain_graph,
#     645         create_graph=create_graph,
#     646         inputs=inputs,
#     647     )
#     648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File ~/miniconda3/envs/cp/lib/python3.10/site-packages/torch/overrides.py:1721, in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1717 if _is_torch_function_mode_enabled():
#    1718     # if we're here, the mode must be set to a TorchFunctionStackMode
#    1719     # this unsets it and calls directly into TorchFunctionStackMode's torch function
#    1720     with _pop_mode_temporarily() as mode:
# -> 1721         result = mode.__torch_function__(public_api, types, args, kwargs)
#    1722     if result is not NotImplemented:
#    1723         return result
#
# File ~/miniconda3/envs/cp/lib/python3.10/site-packages/torch/utils/_device.py:104, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#     102 if func in _device_constructors() and kwargs.get('device') is None:
#     103     kwargs['device'] = self.device
# --> 104 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/cp/lib/python3.10/site-packages/torch/_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)
#     646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File ~/miniconda3/envs/cp/lib/python3.10/site-packages/torch/autograd/__init__.py:333, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     329     raise RuntimeError("`inputs` argument to `backward()` cannot be empty.")
#     331 if is_tensor_like(tensors) or isinstance(tensors, graph.GradientEdge):
#     332     tensors = cast(
# --> 333         Union[tuple[torch.Tensor], tuple[graph.GradientEdge]], (tensors,)
#     334     )
#     335 else:
#     336     tensors = tuple(tensors)
#
# File ~/miniconda3/envs/cp/lib/python3.10/typing.py:309, in _tp_cache.<locals>.decorator.<locals>.inner(*args, **kwds)
#     306 @functools.wraps(func)
#     307 def inner(*args, **kwds):
#     308     try:
# --> 309         return cached(*args, **kwds)
#     310     except TypeError:
#     311         pass  # All real errors (not unhashable args) are raised below.
#
# KeyboardInterrupt:

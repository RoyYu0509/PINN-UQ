# %%
import torch
import torch.nn as nn
import math
import numpy as np
from interface_pde import BasePDE

from utils_uq_vi import VIBPINN
from utils_pde_damposcillation import DampedOscillator1D
from utils_pde_poisson import Poisson1D
from utils_result_viz import * # plot_truth_and_samples_1D, plot_training_history

if torch.backends.mps.is_available():
    device = torch.device("mps")  # Apple Silicon GPU (M1/M2/M3)
elif torch.cuda.is_available():
    device = torch.device("cuda")  # NVIDIA GPU
else:
    device = torch.device("cpu")   # Fallback to CPU

device = torch.device("cpu")
torch.set_default_device(device)
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Example: 1D Poisson equation, u''(x) = f(x) on [0,1], with u(0)=0, u(1)=0.
# Define f(x) (source term). For example, f(x) = -π^2 * sin(πx) has true solution u(x)=sin(πx) on [0,1] with zero boundary.
omega_true = 2*np.pi    # undamped frequency
zeta_true  = 0.1       # damping ratio
A   = 0.5          # new amplitude
phi = 1.2          # new phase in radians
omega_d = omega_true*np.sqrt(1-zeta_true**2)
t0 = torch.zeros((1, 1), device=device, dtype=torch.float32)  # no grads needed
x0_val = A * math.cos(phi)                     # scalar Python float
v0_val = -A * zeta_true * omega_true * math.cos(phi)  \
        - A * omega_d      * math.sin(phi)
x0 = torch.tensor([[x0_val ]], device=device, dtype=torch.float32)
v0 = torch.tensor([[v0_val]], device=device, dtype=torch.float32)

# %%
# Analytical solution function
def x_true(t):
    # Underdamped solution: A*exp(-zeta*omega*t) * cos(omega_d*t + phi)
    return A * np.exp(-zeta_true*omega_true*t) * np.cos(omega_d*t + phi)


# Define source function: f(x) = -π² sin(πx)
def f_func(x):
    return 0

# %%
data_noise = 0.08

pde = DampedOscillator1D(
    zeta_true,
    omega_true, 
    f_func, 
    (x0, v0),
    (0, 5),
    x_true)

# Generate training and testing data of the poisson function
(X_train, Y_train) = pde.data_generation(300, data_noise)
(X_test, Y_test) = pde.data_generation(100, data_noise)

# Collocation points in (0,5)
x_colloc_num = 50
x_collocation = torch.linspace(0.0, 5.0, steps=x_colloc_num).view(-1, 1)
x_collocation = x_collocation[(x_collocation > 0) & (x_collocation < 1)].view(-1, 1)

# %%
fig, ax = plot_truth_and_samples_1D(
    x0     = 0,
    x1     = 5,
    X_train   = X_train,
    Y_train   = Y_train,
    true_solution=x_true,
    x_colloc = x_collocation,
    title     = "Underdamped oscillator: ground-truth vs noisy data"
)

# %%
# from draft import VIBPINN
vi_oscillation_model = VIBPINN(pde, 1, [16, 32, 32, 16], 1, mu_std=0.05, rho=-3, prior_std=1000.0, init_data_noise=data_noise, learn_data_noise=False)
loss_dict = vi_oscillation_model.fit_vi_bpinn(x_colloc_num, X_train=X_train, Y_train=Y_train, epochs=100000, lr=6e-3,
                               λ_pde=10.0,λ_ic=10.0, λ_elbo=1.0, stop_schedule=20000)
# Out:
# ep     0 | L=7.45e+02 | elbo=6.51e+02 | pde=1.83e-01  ic=9.22e+00  bc=0.00e+00 | lr=6.00e-03 | learned noise_std=8.000e-02
# ep     1 | L=1.24e+03 | elbo=1.14e+03 | pde=3.30e-02  ic=9.22e+00  bc=0.00e+00 | lr=6.00e-03 | learned noise_std=8.000e-02
# ep  1000 | L=1.65e+03 | elbo=6.20e+02 | pde=9.33e+01  ic=9.21e+00  bc=0.00e+00 | lr=6.00e-03 | learned noise_std=8.000e-02
# ep  2000 | L=7.97e+02 | elbo=6.20e+02 | pde=8.37e+00  ic=9.25e+00  bc=0.00e+00 | lr=6.00e-03 | learned noise_std=8.000e-02
# ep  3000 | L=7.21e+02 | elbo=6.25e+02 | pde=3.07e-01  ic=9.25e+00  bc=0.00e+00 | lr=6.00e-03 | learned noise_std=8.000e-02
# ep  4000 | L=7.03e+02 | elbo=6.09e+02 | pde=1.18e-01  ic=9.24e+00  bc=0.00e+00 | lr=6.00e-03 | learned noise_std=8.000e-02
# ep  5000 | L=7.08e+02 | elbo=6.10e+02 | pde=5.22e-01  ic=9.29e+00  bc=0.00e+00 | lr=3.00e-03 | learned noise_std=8.000e-02
# ep  6000 | L=6.95e+02 | elbo=5.93e+02 | pde=7.67e-01  ic=9.48e+00  bc=0.00e+00 | lr=3.00e-03 | learned noise_std=8.000e-02
# ep  7000 | L=6.42e+02 | elbo=5.50e+02 | pde=3.36e-01  ic=8.79e+00  bc=0.00e+00 | lr=3.00e-03 | learned noise_std=8.000e-02
# ep  8000 | L=6.89e+02 | elbo=5.41e+02 | pde=7.12e+00  ic=7.69e+00  bc=0.00e+00 | lr=3.00e-03 | learned noise_std=8.000e-02
# ep  9000 | L=6.13e+02 | elbo=5.35e+02 | pde=1.00e+00  ic=6.83e+00  bc=0.00e+00 | lr=3.00e-03 | learned noise_std=8.000e-02
# ep 10000 | L=5.09e+02 | elbo=4.65e+02 | pde=1.81e+00  ic=2.57e+00  bc=0.00e+00 | lr=1.50e-03 | learned noise_std=8.000e-02
# ep 11000 | L=5.03e+02 | elbo=4.46e+02 | pde=3.53e+00  ic=2.26e+00  bc=0.00e+00 | lr=1.50e-03 | learned noise_std=8.000e-02
# ep 12000 | L=5.24e+02 | elbo=4.90e+02 | pde=6.63e-01  ic=2.73e+00  bc=0.00e+00 | lr=1.50e-03 | learned noise_std=8.000e-02
# ep 13000 | L=4.84e+02 | elbo=4.47e+02 | pde=1.47e+00  ic=2.20e+00  bc=0.00e+00 | lr=1.50e-03 | learned noise_std=8.000e-02
# ep 14000 | L=4.82e+02 | elbo=4.31e+02 | pde=3.08e+00  ic=1.94e+00  bc=0.00e+00 | lr=1.50e-03 | learned noise_std=8.000e-02
# ep 15000 | L=4.73e+02 | elbo=4.42e+02 | pde=1.07e+00  ic=1.98e+00  bc=0.00e+00 | lr=7.50e-04 | learned noise_std=8.000e-02
# ep 16000 | L=4.46e+02 | elbo=4.24e+02 | pde=1.49e+00  ic=7.88e-01  bc=0.00e+00 | lr=7.50e-04 | learned noise_std=8.000e-02
# ep 17000 | L=4.41e+02 | elbo=4.18e+02 | pde=1.81e+00  ic=5.12e-01  bc=0.00e+00 | lr=7.50e-04 | learned noise_std=8.000e-02
# ep 18000 | L=4.71e+02 | elbo=4.22e+02 | pde=4.22e+00  ic=6.89e-01  bc=0.00e+00 | lr=7.50e-04 | learned noise_std=8.000e-02
# ep 19000 | L=4.90e+02 | elbo=4.56e+02 | pde=2.41e+00  ic=9.54e-01  bc=0.00e+00 | lr=7.50e-04 | learned noise_std=8.000e-02
# ep 20000 | L=4.35e+02 | elbo=4.11e+02 | pde=1.90e+00  ic=4.73e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 21000 | L=4.28e+02 | elbo=4.03e+02 | pde=1.95e+00  ic=4.62e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 22000 | L=4.33e+02 | elbo=4.10e+02 | pde=2.00e+00  ic=3.11e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 23000 | L=4.35e+02 | elbo=4.03e+02 | pde=2.89e+00  ic=2.87e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 24000 | L=4.22e+02 | elbo=3.95e+02 | pde=2.46e+00  ic=2.42e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 25000 | L=4.19e+02 | elbo=3.92e+02 | pde=2.35e+00  ic=3.48e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 26000 | L=4.82e+02 | elbo=4.02e+02 | pde=7.54e+00  ic=4.10e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 27000 | L=4.37e+02 | elbo=4.06e+02 | pde=2.88e+00  ic=2.29e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 28000 | L=4.25e+02 | elbo=3.94e+02 | pde=2.74e+00  ic=3.54e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 29000 | L=4.45e+02 | elbo=4.24e+02 | pde=1.95e+00  ic=1.38e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 30000 | L=4.19e+02 | elbo=3.95e+02 | pde=2.30e+00  ic=1.59e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 31000 | L=4.25e+02 | elbo=3.98e+02 | pde=2.53e+00  ic=1.90e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 32000 | L=4.09e+02 | elbo=3.90e+02 | pde=1.74e+00  ic=9.76e-02  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 33000 | L=4.17e+02 | elbo=3.88e+02 | pde=2.87e+00  ic=9.15e-02  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 34000 | L=4.18e+02 | elbo=3.92e+02 | pde=2.52e+00  ic=7.94e-02  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 35000 | L=4.12e+02 | elbo=3.85e+02 | pde=2.71e+00  ic=1.51e-02  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 36000 | L=4.11e+02 | elbo=3.84e+02 | pde=2.60e+00  ic=7.96e-02  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 37000 | L=4.05e+02 | elbo=3.80e+02 | pde=2.42e+00  ic=9.89e-02  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 38000 | L=4.09e+02 | elbo=3.82e+02 | pde=2.62e+00  ic=6.35e-02  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 39000 | L=4.09e+02 | elbo=3.83e+02 | pde=2.38e+00  ic=1.68e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 40000 | L=4.16e+02 | elbo=3.75e+02 | pde=4.14e+00  ic=4.11e-02  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 41000 | L=3.98e+02 | elbo=3.73e+02 | pde=2.42e+00  ic=1.03e-01  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep
-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 73000 | L=2.06e+02 | elbo=2.04e+02 | pde=2.03e-01  ic=2.15e-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 74000 | L=2.06e+02 | elbo=2.03e+02 | pde=2.45e-01  ic=1.98e-04  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 75000 | L=2.04e+02 | elbo=2.02e+02 | pde=1.91e-01  ic=2.00e-02  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 76000 | L=2.05e+02 | elbo=2.03e+02 | pde=1.85e-01  ic=3.41e-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 77000 | L=2.06e+02 | elbo=2.05e+02 | pde=1.57e-01  ic=3.96e-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 78000 | L=2.07e+02 | elbo=2.04e+02 | pde=2.99e-01  ic=8.42e-05  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 79000 | L=2.04e+02 | elbo=2.02e+02 | pde=1.75e-01  ic=2.42e-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 80000 | L=2.05e+02 | elbo=2.03e+02 | pde=1.92e-01  ic=8.80e-04  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 81000 | L=2.03e+02 | elbo=2.02e+02 | pde=1.30e-01  ic=1.11e-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 82000 | L=2.04e+02 | elbo=2.02e+02 | pde=2.00e-01  ic=6.07e-04  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 83000 | L=2.03e+02 | elbo=2.01e+02 | pde=1.64e-01  ic=2.40e-04  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 84000 | L=2.03e+02 | elbo=2.01e+02 | pde=1.91e-01  ic=6.72e-04  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 85000 | L=2.03e+02 | elbo=2.02e+02 | pde=1.69e-01  ic=1.45e-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 86000 | L=2.03e+02 | elbo=2.01e+02 | pde=1.37e-01  ic=8.42e-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 87000 | L=2.01e+02 | elbo=2.00e+02 | pde=1.21e-01  ic=1.86e-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 88000 | L=2.03e+02 | elbo=2.02e+02 | pde=8.93e-02  ic=1.56e-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 89000 | L=2.02e+02 | elbo=2.01e+02 | pde=1.27e-01  ic=6.73e-04  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 90000 | L=2.03e+02 | elbo=2.02e+02 | pde=1.08e-01  ic=1.21e-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 91000 | L=2.04e+02 | elbo=2.03e+02 | pde=1.53e-01  ic=1.69e-04  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 92000 | L=2.02e+02 | elbo=2.00e+02 | pde=1.36e-01  ic=6.17e-04  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 93000 | L=2.03e+02 | elbo=2.01e+02 | pde=1.93e-01  ic=1.76e-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 94000 | L=2.05e+02 | elbo=2.03e+02 | pde=2.26e-01  ic=5.91e-04  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 95000 | L=2.02e+02 | elbo=2.01e+02 | pde=1.69e-01  ic=1.53e-04  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 96000 | L=2.00e+02 | elbo=1.99e+02 | pde=1.52e-01  ic=1.12e-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 97000 | L=2.00e+02 | elbo=1.99e+02 | pde=1.28e-01  ic=1.41e-03  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 98000 | L=2.02e+02 | elbo=2.01e+02 | pde=1.04e-01  ic=3.33e-04  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02
# ep 99000 | L=2.04e+02 | elbo=2.00e+02 | pde=3.52e-01  ic=9.40e-04  bc=0.00e+00 | lr=3.75e-04 | learned noise_std=8.000e-02

# %%
plot_training_history(loss_dict, plot_after=0, step=100)

# %%
x_grid = torch.linspace(0, 5, 100).view(-1, 1)
pred_set = vi_oscillation_model.predict(x_grid, n_samples=1000, z_score=1.69)

# %%
plot_predictions_1D(x_grid, pred_set, x_true, X=X_train, Y=Y_train)

# %% [markdown]
# # Imports

# %%
import torch
import torch.nn as nn
import math
import numpy as np
from interface_pde import BasePDE

from utils_uq_vi import VIBPINN
from utils_pde_damposcillation import DampedOscillator1D
from utils_pde_poisson import Poisson1D
from utils_result_viz import * # plot_truth_and_samples_1D, plot_training_history

if torch.backends.mps.is_available():
    device = torch.device("mps")  # Apple Silicon GPU (M1/M2/M3)
elif torch.cuda.is_available():
    device = torch.device("cuda")  # NVIDIA GPU
else:
    device = torch.device("cpu")   # Fallback to CPU

device = torch.device("cpu")
torch.set_default_device(device)
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %% [markdown]
# # 1D Poisson Equation

# %% [markdown]
# $$\frac{d^2 u}{dx^2} = f(x), \quad x \in (0, 1) \text{ with boundary conditions: $u(0)=0$ and $u(1)=1$}$$
#
# The analytical solution: $u^*(x) = \sin(\pi x)$
#
# The source function: $f(x) = -\pi^2 \sin(\pi x)$
#
# For simplicity of this problem, we denote the input as X and output as Y

# %% [markdown]
# ## Define PDE & Simulate noisy data

# %%
# Analytical solution
u_star = lambda x: np.sin(math.pi * x)


# Define source function: f(x) = -π² sin(πx)
def f_func(x):
    return -(math.pi**2) * torch.sin(math.pi * x)

# %%
data_noise = 0.08

# Instantiate Poisson PDE problem
pde = Poisson1D(f_func=f_func, 
                bc_values=(torch.tensor([[0.0]]), torch.tensor([[0.0]])),
                domain=(0,1), true_solution=u_star)

# Generate training and testing data of the poisson function
(X_train, Y_train) = pde.data_generation(300, data_noise)
(X_test, Y_test) = pde.data_generation(100, data_noise)

# Collocation points in (0,1)
x_colloc_num = 50
x_collocation = torch.linspace(0.0, 1.0, steps=x_colloc_num).view(-1, 1)
x_collocation = x_collocation[(x_collocation > 0) & (x_collocation < 1)].view(-1, 1)

# %%
fig, ax = plot_truth_and_samples_1D(
    x0     = 0,
    x1     = 1,
    X_train   = X_train,
    Y_train   = Y_train,
    true_solution=u_star,
    x_colloc = x_collocation,
    title     = "Underdamped oscillator: ground-truth vs noisy data"
)

# %% [markdown]
# **Parameters for tuning prediction spread:**
#
# - `rho`: define the Bayesian Layer parameters' spread
#
# - `piror_std`: define the piror distribution's std
# - `data_noise_guess`: define the guessed data noise in the loss function - negative log likelihood

# %%
# from draft import VIBPINN

vi_poisson_model = VIBPINN(pde, 1, [16, 32, 32, 16], 1, mu_std=0.05, rho=-3, prior_std=1000.0, init_data_noise=0.01, learn_data_noise=True)
loss_dict = vi_poisson_model.fit_vi_bpinn(x_colloc_num, X_train=X_train, Y_train=Y_train, epochs=20000, lr=3e-3,
                               λ_pde=1.0,λ_ic=0.0,λ_bc=1.0, λ_elbo=1.0)
# Out:
# ep     0 | L=7.16e+05 | elbo=7.13e+05 | pde=2.28e+03  ic=0.00e+00  bc=7.03e-03 | lr=3.00e-03 | learned noise_std=1.000e-02
# ep     1 | L=7.23e+05 | elbo=7.21e+05 | pde=2.28e+03  ic=0.00e+00  bc=1.50e-02 | lr=3.00e-03 | learned noise_std=1.003e-02
# ep   200 | L=8.70e+04 | elbo=8.48e+04 | pde=2.27e+03  ic=0.00e+00  bc=6.53e-01 | lr=3.00e-03 | learned noise_std=1.369e-02
# ep   400 | L=6.06e+04 | elbo=5.83e+04 | pde=2.27e+03  ic=0.00e+00  bc=9.03e-01 | lr=3.00e-03 | learned noise_std=1.750e-02
# ep   600 | L=3.69e+04 | elbo=3.46e+04 | pde=2.27e+03  ic=0.00e+00  bc=5.50e-01 | lr=3.00e-03 | learned noise_std=2.144e-02
# ep   800 | L=2.70e+04 | elbo=2.48e+04 | pde=2.27e+03  ic=0.00e+00  bc=5.62e-01 | lr=3.00e-03 | learned noise_std=2.543e-02
# ep  1000 | L=2.05e+04 | elbo=1.83e+04 | pde=2.27e+03  ic=0.00e+00  bc=7.72e-01 | lr=3.00e-03 | learned noise_std=2.947e-02
# ep  1200 | L=1.64e+04 | elbo=1.41e+04 | pde=2.27e+03  ic=0.00e+00  bc=7.39e-01 | lr=3.00e-03 | learned noise_std=3.352e-02
# ep  1400 | L=1.36e+04 | elbo=1.13e+04 | pde=2.27e+03  ic=0.00e+00  bc=8.38e-01 | lr=3.00e-03 | learned noise_std=3.763e-02
# ep  1600 | L=1.14e+04 | elbo=9.16e+03 | pde=2.27e+03  ic=0.00e+00  bc=7.76e-01 | lr=3.00e-03 | learned noise_std=4.179e-02
# ep  1800 | L=9.74e+03 | elbo=7.47e+03 | pde=2.28e+03  ic=0.00e+00  bc=6.87e-01 | lr=3.00e-03 | learned noise_std=4.606e-02
# ep  2000 | L=8.50e+03 | elbo=6.23e+03 | pde=2.27e+03  ic=0.00e+00  bc=8.30e-01 | lr=3.00e-03 | learned noise_std=5.041e-02
# ep  2200 | L=8.23e+03 | elbo=5.96e+03 | pde=2.27e+03  ic=0.00e+00  bc=7.39e-01 | lr=3.00e-03 | learned noise_std=5.487e-02
# ep  2400 | L=6.99e+03 | elbo=4.73e+03 | pde=2.26e+03  ic=0.00e+00  bc=5.82e-01 | lr=3.00e-03 | learned noise_std=5.944e-02
# ep  2600 | L=6.13e+03 | elbo=3.88e+03 | pde=2.25e+03  ic=0.00e+00  bc=7.95e-01 | lr=3.00e-03 | learned noise_std=6.415e-02
# ep  2800 | L=5.60e+03 | elbo=3.34e+03 | pde=2.26e+03  ic=0.00e+00  bc=8.21e-01 | lr=3.00e-03 | learned noise_std=6.902e-02
# ep  3000 | L=5.20e+03 | elbo=2.96e+03 | pde=2.24e+03  ic=0.00e+00  bc=7.05e-01 | lr=3.00e-03 | learned noise_std=7.405e-02
# ep  3200 | L=4.78e+03 | elbo=2.53e+03 | pde=2.25e+03  ic=0.00e+00  bc=8.41e-01 | lr=3.00e-03 | learned noise_std=7.926e-02
# ep  3400 | L=4.53e+03 | elbo=2.29e+03 | pde=2.24e+03  ic=0.00e+00  bc=7.58e-01 | lr=3.00e-03 | learned noise_std=8.463e-02
# ep  3600 | L=4.25e+03 | elbo=2.03e+03 | pde=2.21e+03  ic=0.00e+00  bc=8.33e-01 | lr=3.00e-03 | learned noise_std=9.018e-02
# ep  3800 | L=3.82e+03 | elbo=1.71e+03 | pde=2.11e+03  ic=0.00e+00  bc=6.57e-01 | lr=3.00e-03 | learned noise_std=9.593e-02
# ep  4000 | L=2.88e+03 | elbo=1.39e+03 | pde=1.48e+03  ic=0.00e+00  bc=6.54e-01 | lr=3.00e-03 | learned noise_std=1.016e-01
# ep  4200 | L=1.26e+03 | elbo=7.31e+02 | pde=5.28e+02  ic=0.00e+00  bc=4.41e-01 | lr=3.00e-03 | learned noise_std=1.063e-01
# ep  4400 | L=8.72e+02 | elbo=4.83e+02 | pde=3.88e+02  ic=0.00e+00  bc=3.73e-01 | lr=3.00e-03 | learned noise_std=1.092e-01
# ep  4600 | L=5.99e+02 | elbo=3.28e+02 | pde=2.71e+02  ic=0.00e+00  bc=2.31e-01 | lr=3.00e-03 | learned noise_std=1.118e-01
# ep  4800 | L=5.48e+02 | elbo=3.35e+02 | pde=2.13e+02  ic=0.00e+00  bc=7.64e-02 | lr=3.00e-03 | learned noise_std=1.143e-01
# ep  5000 | L=4.34e+02 | elbo=3.24e+02 | pde=1.11e+02  ic=0.00e+00  bc=1.54e-01 | lr=1.50e-03 | learned noise_std=1.167e-01
# ep  5200 | L=4.82e+02 | elbo=3.69e+02 | pde=1.14e+02  ic=0.00e+00  bc=1.22e-01 | lr=1.50e-03 | learned noise_std=1.179e-01
# ep  5400 | L=2.53e+02 | elbo=1.90e+02 | pde=6.23e+01  ic=0.00e+00  bc=1.98e-01 | lr=1.50e-03 | learned noise_std=1.191e-01
# ep  5600 | L=2.46e+02 | elbo=1.81e+02 | pde=6.47e+01  ic=0.00e+00  bc=1.40e-01 | lr=1.50e-03 | learned noise_std=1.202e-01
# ep  5800 | L=1.85e+02 | elbo=1.44e+02 | pde=4.04e+01  ic=0.00e+00  bc=1.81e-01 | lr=1.50e-03 | learned noise_std=1.216e-01
# ep  6000 | L=1.70e+02 | elbo=1.47e+02 | pde=2.28e+01  ic=0.00e+00  bc=4.61e-02 | lr=1.50e-03 | learned noise_std=1.230e-01
# ep  6200 | L=1.58e+02 | elbo=1.31e+02 | pde=2.68e+01  ic=0.00e+00  bc=1.43e-01 | lr=1.50e-03 | learned noise_std=1.244e-01
# ep  6400 | L=2.18e+02 | elbo=1.92e+02 | pde=2.66e+01  ic=0.00e+00  bc=3.55e-02 | lr=1.50e-03 | learned noise_std=1.259e-01
# ep  6600 | L=2.30e+02 | elbo=2.14e+02 | pde=1.61e+01  ic=0.00e+00  bc=1.76e-03 | lr=1.50e-03 | learned noise_std=1.275e-01
# ep  6800 | L=1.49e+02 | elbo=1.30e+02 | pde=1.92e+01  ic=0.00e+00  bc=3.48e-03 | lr=1.50e-03 | learned noise_std=1.292e-01
# ep  7000 | L=8.69e+01 | elbo=8.15e+01 | pde=5.41e+00  ic=0.00e+00  bc=3.71e-02 | lr=1.50e-03 | learned noise_std=1.311e-01
# ep  7200 | L=1.02e+02 | elbo=9.60e+01 | pde=6.11e+00  ic=0.00e+00  bc=4.48e-02 | lr=1.50e-03 | learned noise_std=1.330e-01
# ep  7400 | L=8.07e+01 | elbo=7.57e+01 | pde=4.91e+00  ic=0.00e+00  bc=6.55e-04 | lr=1.50e-03 | learned noise_std=1.348e-01
# ep  7600 | L=9.69e+01 | elbo=9.46e+01 | pde=2.29e+00  ic=0.00e+00  bc=3.42e-02 | lr=1.50e-03 | learned noise_std=1.369e-01
# ep  7800 | L=9.44e+01 | elbo=9.06e+01 | pde=3.82e+00  ic=0.00e+00  bc=4.35e-03 | lr=1.50e-03 | learned noise_std=1.390e-01
# ep  8000 | L=7.86e+01 | elbo=7.15e+01 | pde=7.07e+00  ic=0.00e+00  bc=6.66e-02 | lr=1.50e-03 | learned noise_std=1.414e-01
# ep  8200 | L=4.36e+02 | elbo=4.34e+02 | pde=1.92e+00  ic=0.00e+00  bc=7.28e-03 | lr=1.50e-03 | learned noise_std=1.441e-01
# ep  8400 | L=2.15e+02 | elbo=2.11e+02 | pde=4.55e+00  ic=0.00e+00  bc=3.38e-02 | lr=1.50e-03 | learned noise_std=1.469e-01
# ep  8600 | L=8.09e+01 | elbo=7.93e+01 | pde=1.53e+00  ic=0.00e+00  bc=2.85e-02 | lr=1.50e-03 | learned noise_std=1.499e-01
# ep  8800 | L=7.97e+01 | elbo=7.81e+01 | pde=1.47e+00  ic=0.00e+00  bc=4.26e-02 | lr=1.50e-03 | learned noise_std=1.530e-01
# ep  9000 | L=8.24e+01 | elbo=8.07e+01 | pde=1.67e+00  ic=0.00e+00  bc=1.74e-02 | lr=1.50e-03 | learned noise_std=1.561e-01
# ep  9200 | L=1.06e+02 | elbo=1.04e+02 | pde=1.66e+00  ic=0.00e+00  bc=5.29e-02 | lr=1.50e-03 | learned noise_std=1.597e-01
# ep  9400 | L=9.23e+01 | elbo=9.02e+01 | pde=2.11e+00  ic=0.00e+00  bc=5.03e-02 | lr=1.50e-03 | learned noise_std=1.632e-01
# ep  9600 | L=7.76e+01 | elbo=7.67e+01 | pde=8.87e-01  ic=0.00e+00  bc=1.27e-03 | lr=1.50e-03 | learned noise_std=1.672e-01
# ep  9800 | L=5.30e+01 | elbo=5.23e+01 | pde=6.08e-01  ic=0.00e+00  bc=4.10e-03 | lr=1.50e-03 | learned noise_std=1.712e-01
# ep 10000 | L=7.35e+01 | elbo=7.27e+01 | pde=8.56e-01  ic=0.00e+00  bc=2.11e-02 | lr=7.50e-04 | learned noise_std=1.754e-01
# ep 10200 | L=6.14e+01 | elbo=6.01e+01 | pde=1.31e+00  ic=0.00e+00  bc=2.10e-03 | lr=7.50e-04 | learned noise_std=1.775e-01
# ep 10400 | L=6.09e+01 | elbo=5.99e+01 | pde=9.59e-01  ic=0.00e+00  bc=6.49e-03 | lr=7.50e-04 | learned noise_std=1.800e-01
# ep 10600 | L=5.28e+01 | elbo=4.91e+01 | pde=3.71e+00  ic=0.00e+00  bc=1.03e-02 | lr=7.50e-04 | learned noise_std=1.826e-01
# ep 10800 | L=4.45e+01 | elbo=4.22e+01 | pde=2.28e+00  ic=0.00e+00  bc=2.96e-02 | lr=7.50e-04 | learned noise_std=1.853e-01
# ep 11000 | L=4.40e+01 | elbo=4.21e+01 | pde=1.94e+00  ic=0.00e+00  bc=1.98e-03 | lr=7.50e-04 | learned noise_std=1.882e-01
# ep 11200 | L=4.28e+01 | elbo=4.23e+01 | pde=4.86e-01  ic=0.00e+00  bc=1.34e-02 | lr=7.50e-04 | learned noise_std=1.915e-01
# ep 11400 | L=6.53e+01 | elbo=6.42e+01 | pde=1.08e+00  ic=0.00e+00  bc=1.36e-02 | lr=7.50e-04 | learned noise_std=1.952e-01
# ep 11600 | L=6.74e+01 | elbo=6.68e+01 | pde=5.78e-01  ic=0.00e+00  bc=6.03e-03 | lr=7.50e-04 | learned noise_std=1.988e-01
# ep 11800 | L=5.50e+01 | elbo=5.45e+01 | pde=5.15e-01  ic=0.00e+00  bc=6.00e-03 | lr=7.50e-04 | learned noise_std=2.029e-01
# ep 12000 | L=6.06e+01 | elbo=5.92e+01 | pde=1.33e+00  ic=0.00e+00  bc=6.50e-03 | lr=7.50e-04 | learned noise_std=2.071e-01
# ep 12200 | L=4.48e+01 | elbo=4.45e+01 | pde=2.53e-01  ic=0.00e+00  bc=2.39e-02 | lr=7.50e-04 | learned noise_std=2.117e-01
# ep 12400 | L=3.31e+01 | elbo=3.27e+01 | pde=4.68e-01  ic=0.00e+00  bc=1.86e-02 | lr=7.50e-04 | learned noise_std=2.168e-01
# ep 12600 | L=3.25e+01 | elbo=3.20e+01 | pde=5.17e-01  ic=0.00e+00  bc=2.61e-03 | lr=7.50e-04 | learned noise_std=2.224e-01
# ep 12800 | L=3.73e+01 | elbo=3.71e+01 | pde=1.69e-01  ic=0.00e+00  bc=1.88e-02 | lr=7.50e-04 | learned noise_std=2.281e-01
# ep 13000 | L=4.57e+01 | elbo=4.53e+01 | pde=3.96e-01  ic=0.00e+00  bc=7.47e-03 | lr=7.50e-04 | learned noise_std=2.338e-01
# ep 13200 | L=3.42e+01 | elbo=3.41e+01 | pde=8.66e-02  ic=0.00e+00  bc=1.39e-03 | lr=7.50e-04 | learned noise_std=2.403e-01
# ep 13400 | L=3.47e+01 | elbo=3.46e+01 | pde=1.43e-01  ic=0.00e+00  bc=9.72e-03 | lr=7.50e-04 | learned noise_std=2.472e-01
# ep 13600 | L=3.23e+01 | elbo=3.13e+01 | pde=9.33e-01  ic=0.00e+00  bc=1.95e-03 | lr=7.50e-04 | learned noise_std=2.544e-01
# ep 13800 | L=3.17e+01 | elbo=3.12e+01 | pde=4.66e-01  ic=0.00e+00  bc=1.27e-02 | lr=7.50e-04 | learned noise_std=2.623e-01
# ep 14000 | L=2.76e+01 | elbo=2.72e+01 | pde=4.26e-01  ic=0.00e+00  bc=4.37e-04 | lr=7.50e-04 | learned noise_std=2.699e-01
# ep 14200 | L=2.86e+01 | elbo=2.84e+01 | pde=1.98e-01  ic=0.00e+00  bc=4.15e-03 | lr=7.50e-04 | learned noise_std=2.779e-01
# ep 14400 | L=3.82e+01 | elbo=3.74e+01 | pde=7.96e-01  ic=0.00e+00  bc=1.18e-02 | lr=7.50e-04 | learned noise_std=2.870e-01
# ep 14600 | L=3.96e+01 | elbo=3.92e+01 | pde=4.01e-01  ic=0.00e+00  bc=1.15e-02 | lr=7.50e-04 | learned noise_std=2.965e-01
# ep 14800 | L=4.14e+01 | elbo=4.10e+01 | pde=4.39e-01  ic=0.00e+00  bc=1.40e-02 | lr=7.50e-04 | learned noise_std=3.069e-01
# ep 15000 | L=3.38e+01 | elbo=3.35e+01 | pde=2.75e-01  ic=0.00e+00  bc=1.32e-02 | lr=3.75e-04 | learned noise_std=3.176e-01
# ep 15200 | L=1.99e+01 | elbo=1.97e+01 | pde=1.65e-01  ic=0.00e+00  bc=3.49e-04 | lr=3.75e-04 | learned noise_std=3.230e-01
# ep 15400 | L=2.34e+01 | elbo=2.33e+01 | pde=1.41e-01  ic=0.00e+00  bc=2.27e-03 | lr=3.75e-04 | learned noise_std=3.291e-01
# ep 15600 | L=2.41e+01 | elbo=2.41e+01 | pde=2.07e-02  ic=0.00e+00  bc=3.23e-03 | lr=3.75e-04 | learned noise_std=3.354e-01
# ep 15800 | L=2.17e+01 | elbo=2.14e+01 | pde=3.60e-01  ic=0.00e+00  bc=7.18e-04 | lr=3.75e-04 | learned noise_std=3.423e-01
# ep 16000 | L=4.37e+01 | elbo=4.35e+01 | pde=2.29e-01  ic=0.00e+00  bc=2.38e-03 | lr=3.75e-04 | learned noise_std=3.499e-01
# ep 16200 | L=2.77e+01 | elbo=2.77e+01 | pde=7.05e-02  ic=0.00e+00  bc=4.71e-04 | lr=3.75e-04 | learned noise_std=3.579e-01
# ep 16400 | L=1.74e+01 | elbo=1.73e+01 | pde=1.08e-01  ic=0.00e+00  bc=1.81e-02 | lr=3.75e-04 | learned noise_std=3.664e-01
# ep 16600 | L=2.14e+01 | elbo=2.11e+01 | pde=3.71e-01  ic=0.00e+00  bc=1.96e-03 | lr=3.75e-04 | learned noise_std=3.752e-01
# ep 16800 | L=1.66e+01 | elbo=1.66e+01 | pde=7.58e-02  ic=0.00e+00  bc=2.52e-03 | lr=3.75e-04 | learned noise_std=3.848e-01
# ep 17000 | L=1.66e+01 | elbo=1.62e+01 | pde=4.46e-01  ic=0.00e+00  bc=2.68e-03 | lr=3.75e-04 | learned noise_std=3.951e-01
# ep 17200 | L=1.65e+01 | elbo=1.63e+01 | pde=1.45e-01  ic=0.00e+00  bc=8.46e-03 | lr=3.75e-04 | learned noise_std=4.054e-01
# ep 17400 | L=1.55e+01 | elbo=1.54e+01 | pde=2.55e-02  ic=0.00e+00  bc=4.90e-03 | lr=3.75e-04 | learned noise_std=4.167e-01
# ep 17600 | L=1.60e+01 | elbo=1.58e+01 | pde=1.16e-01  ic=0.00e+00  bc=3.77e-03 | lr=3.75e-04 | learned noise_std=4.286e-01
# ep 17800 | L=1.56e+01 | elbo=1.55e+01 | pde=7.67e-02  ic=0.00e+00  bc=1.31e-02 | lr=3.75e-04 | learned noise_std=4.412e-01
# ep 18000 | L=1.46e+01 | elbo=1.45e+01 | pde=9.63e-02  ic=0.00e+00  bc=3.15e-03 | lr=3.75e-04 | learned noise_std=4.541e-01
# ep 18200 | L=1.89e+01 | elbo=1.88e+01 | pde=7.08e-02  ic=0.00e+00  bc=1.09e-02 | lr=3.75e-04 | learned noise_std=4.680e-01
# ep 18400 | L=1.53e+01 | elbo=1.52e+01 | pde=1.29e-01  ic=0.00e+00  bc=1.76e-03 | lr=3.75e-04 | learned noise_std=4.831e-01
# ep 18600 | L=1.41e+01 | elbo=1.40e+01 | pde=3.08e-02  ic=0.00e+00  bc=5.27e-03 | lr=3.75e-04 | learned noise_std=4.980e-01
# ep 18800 | L=1.35e+01 | elbo=1.35e+01 | pde=5.78e-02  ic=0.00e+00  bc=1.16e-03 | lr=3.75e-04 | learned noise_std=5.142e-01
# ep 19000 | L=1.39e+01 | elbo=1.38e+01 | pde=6.30e-02  ic=0.00e+00  bc=4.79e-02 | lr=3.75e-04 | learned noise_std=5.308e-01
# ep 19200 | L=1.28e+01 | elbo=1.28e+01 | pde=1.97e-02  ic=0.00e+00  bc=1.58e-02 | lr=3.75e-04 | learned noise_std=5.485e-01
# ep 19400 | L=1.41e+01 | elbo=1.41e+01 | pde=4.38e-02  ic=0.00e+00  bc=3.70e-03 | lr=3.75e-04 | learned noise_std=5.670e-01
# ep 19600 | L=1.36e+01 | elbo=1.36e+01 | pde=3.76e-02  ic=0.00e+00  bc=1.77e-03 | lr=3.75e-04 | learned noise_std=5.860e-01
# ep 19800 | L=1.26e+01 | elbo=1.25e+01 | pde=7.82e-02  ic=0.00e+00  bc=4.44e-03 | lr=3.75e-04 | learned noise_std=6.055e-01

# %%
plot_training_history(loss_dict, plot_after=0, step=100)

# %%
x_grid = torch.linspace(0, 1, 100).view(-1, 1)
pred_set = vi_poisson_model.predict(x_grid, n_samples=1000, z_score=1.96)

# %%
plot_predictions_1D(x_grid, pred_set, u_star, X=X_train, Y=Y_train)

# %% [markdown]
# ## Sharpness & Coverage

# %%
from utils_result_metrics import test_uncertainties
def generating_alphas(a_num):
    alphas = torch.linspace(0.0, 1.0, 10).view(-1, 1)
    return alphas[1:a_num-1]

alphas = generating_alphas(10)

rslt = test_uncertainties(vi_poisson_model, alphas, X_test, Y_test)
# Out:
# 100%|██████████| 8/8 [00:00<00:00, 94.80it/s]

# %%
rslt
# Out:
#       alpha  coverage  sharpness
# 0  0.111111      0.68   0.150621
# 1  0.222222      0.40   0.101859
# 2  0.333333      0.44   0.098883
# 3  0.444444      0.29   0.068747
# 4  0.555556      0.20   0.051841
# 5  0.666667      0.13   0.036770
# 6  0.777778      0.10   0.025513
# 7  0.888889      0.06   0.011844

# %%
from utils_result_viz import plot_expected_vs_empirical

plot_expected_vs_empirical(rslt)

# %% [markdown]
# ## Uncertainty Plot

# %%
def plot_uncertainty(pred_set, x_grid):
    """
    Plot the uncertainty (interval width) over the grid.

    Parameters:
    - pred_set: tuple or list containing (lower_bounds, upper_bounds)
    - x_grid: 1D array of x values (same length as pred_set[0] and pred_set[1])
    """
    lower_bounds = np.array(pred_set[0])
    upper_bounds = np.array(pred_set[1])
    uncertainty = (upper_bounds - lower_bounds)

    plt.figure(figsize=(8, 5))
    plt.plot(x_grid, uncertainty, label='Uncertainty Width')
    plt.xlabel('x')
    plt.ylabel('Prediction Interval Width')
    plt.title('Uncertainty Across Input Grid')
    plt.grid(True)
    plt.legend()
    plt.show()

# %%
plot_uncertainty(pred_set, x_grid)
